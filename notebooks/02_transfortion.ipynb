# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from pipeline.integrity import tables_cleaning
from pipeline.transformation import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 from pipeline.integrity import tables_cleaning
#       2 from pipeline.transformation import *
#
# File c:\Users\ADMIN\Desktop\pfaproject\pipeline\integrity.py:3
#       1 import pandas as pd
#       2 import duckdb
# ----> 3 from clean_attributes import (
#       4     clean_transfers,
#       5     clean_microbiologyevents,
#       6     clean_emar
#       7 )
#       8 def tables_cleaning():
#       9     patients = pd.read_csv("data/patients.csv.gz")
#
# ModuleNotFoundError: No module named 'clean_attributes'

# %%
df_admissions = admissions_joiture(tables["admissions"])
print("first rows of df_admissions:")
print(df_admissions.head())
# Out:
# first rows of df_admissions:
#    subject_id   hadm_id event_type          event_time event_value  \
# 0    10004235  24181354  admission 2196-02-24 14:38:00      URGENT
# 1    10009628  25926192  admission 2153-09-17 17:08:00      URGENT
# 2    10018081  23983182  admission 2134-08-18 02:02:00      URGENT
# 3    10006053  22942076  admission 2111-11-13 23:39:00      URGENT
# 4    10031404  21606243  admission 2113-08-04 18:46:00      URGENT
#
#    order_hint provider_id          event_location
# 0         NaN      P03YMR  TRANSFER FROM HOSPITAL
# 1         NaN      P41R5N  TRANSFER FROM HOSPITAL
# 2         NaN      P233F6  TRANSFER FROM HOSPITAL
# 3         NaN      P38TI6  TRANSFER FROM HOSPITAL
# 4         NaN      P07HDB  TRANSFER FROM HOSPITAL

# %%
df_diagnoses = diagnoses_joiture(tables["diagnoses_icd"], tables["d_icd_diagnoses"], tables["admissions"])
print("first rows of df_diagnoses:")
print(df_diagnoses.head())
# Out:
# first rows of df_diagnoses:
#    subject_id   hadm_id event_type          event_time  \
# 0    10037928  24656677  diagnosis 2178-12-21 05:30:00
# 1    10039708  20572787  diagnosis 2138-10-30 23:30:00
# 2    10018845  21101111  diagnosis 2184-10-08 02:28:00
# 3    10037861  24256866  diagnosis 2115-10-09 20:28:00
# 4    10005348  25239799  diagnosis 2130-10-26 17:03:00
#
#                                          event_value  order_hint  provider_id  \
# 0   Other and unspecified Escherichia coli [E. coli]           5          NaN
# 1  Other and unspecified manifestations of thiami...           1          NaN
# 2                    Chronic kidney disease, Stage V           3          NaN
# 3                                 Calculus of kidney          21          NaN
# 4  Osteoarthrosis, unspecified whether generalize...          11          NaN
#
#    event_location
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
df_procedures = procedures_joiture(tables["procedures_icd"], tables["d_icd_procedures"])
print("first rows of df_procedures:")  
print(df_procedures.head())
# Out:
# first rows of df_procedures:
#    subject_id   hadm_id event_type event_time  \
# 0    10039997  24294180  procedure 2134-09-07
# 1    10038933  25129047  procedure 2148-09-11
# 2    10025612  23403708  procedure 2125-09-25
# 3    10027445  29163082  procedure 2142-09-03
# 4    10013049  22675517  procedure 2114-06-20
#
#                                          event_value  order_hint  provider_id  \
# 0                    Other computer assisted surgery           2          NaN
# 1    Other diagnostic procedures on lung or bronchus           1          NaN
# 2                         Other repair of chest wall           7          NaN
# 3                 Percutaneous balloon valvuloplasty           1          NaN
# 4  Excision or destruction of other lesion or tis...           1          NaN
#
#    event_location
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
df_prescriptions = prescriptions_joiture(tables["prescriptions"])
print("first rows of df_prescriptions:")
print(df_prescriptions.head())
# Out:
# first rows of df_prescriptions:
#    subject_id   hadm_id    event_type          event_time       event_value  \
# 0    10027602  28166872  prescription 2201-10-30 12:00:00  Fentanyl Citrate
# 1    10027602  28166872  prescription 2201-10-30 12:00:00  Fentanyl Citrate
# 2    10027602  28166872  prescription 2201-10-31 12:00:00         Lorazepam
# 3    10027602  28166872  prescription 2201-10-30 12:00:00         Midazolam
# 4    10027602  28166872  prescription 2201-10-30 12:00:00         Midazolam
#
#    order_hint provider_id  event_location
# 0         NaN        None             NaN
# 1         NaN        None             NaN
# 2         NaN        None             NaN
# 3         NaN        None             NaN
# 4         NaN        None             NaN

# %%
df_transfers= transfers_joiture(tables["transfers_cleann"])
print("first rows of df_transfers:")
print(df_transfers.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df_transfers= transfers_joiture(tables["transfers_cleann"])
#       2 print("first rows of df_transfers:")
#       3 print(df_transfers.head())
#
# KeyError: 'transfers_cleann'

# %%
df_emar= emar_joiture(tables["emar"])
print("first rows of df_emar:")
print(df_emar.head())
# Out:
# first rows of df_emar:
#    subject_id     hadm_id                 event_type          event_time  \
# 0    10005909  20199380.0  medication_administration 2144-10-31 05:56:00
# 1    10005909  20199380.0  medication_administration 2144-10-31 08:00:00
# 2    10008287  22168393.0  medication_administration 2145-09-28 20:15:00
# 3    10010471  21322534.0  medication_administration 2155-05-08 21:45:00
# 4    10015272  27993466.0  medication_administration 2137-06-13 08:36:00
#
#                                          event_value  order_hint provider_id  \
# 0                                  Magnesium Sulfate         NaN        None
# 1                                  Magnesium Sulfate         NaN        None
# 2  Potassium Chloride Replacement (Critical Care ...         NaN      P26PKF
# 3                                Metoprolol Tartrate         NaN        None
# 4                                Metoprolol Tartrate         NaN        None
#
#    event_location
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
df_hcpcsevents= hcpcsevents_joiture(tables["hcpcsevents"])
print("first rows of df_hcpcsevents:")
print(df_hcpcsevents.head())
# Out:
# first rows of df_hcpcsevents:
#    subject_id   hadm_id event_type event_time     event_value  order_hint  \
# 0    10005348  29176490  hcpcs_act 2129-05-22  Cardiovascular           1
# 1    10005348  29176490  hcpcs_act 2129-05-22  Cardiovascular           2
# 2    10004457  21039249  hcpcs_act 2140-09-17  Cardiovascular           1
# 3    10004457  25559382  hcpcs_act 2148-09-14  Cardiovascular           1
# 4    10039708  27504040  hcpcs_act 2142-07-06  Nervous system           2
#
#    provider_id  event_location
# 0          NaN             NaN
# 1          NaN             NaN
# 2          NaN             NaN
# 3          NaN             NaN
# 4          NaN             NaN

# %%
df_microbiologyevents= microbiologyevents_joiture(tables["microbiologyevents"])
print("first rows of df_microbiologyevents:")
print(df_microbiologyevents.head())
# Out:
# first rows of df_microbiologyevents:
#    subject_id     hadm_id           event_type event_time  \
# 0    10000032  25742920.0  microbiology_result 2180-08-06
# 1    10000032  22595853.0  microbiology_result 2180-05-07
# 2    10000032  29079034.0  microbiology_result 2180-07-24
# 3    10020944  29974575.0  microbiology_result 2131-02-27
# 4    10037975  27617929.0  microbiology_result 2185-01-17
#
#                              event_value  order_hint  provider_id  \
# 0  R/O VANCOMYCIN RESISTANT ENTEROCOCCUS         NaN          NaN
# 1  R/O VANCOMYCIN RESISTANT ENTEROCOCCUS         NaN          NaN
# 2  R/O VANCOMYCIN RESISTANT ENTEROCOCCUS         NaN          NaN
# 3      ENTEROCOCCUS SP. - VANCOMYCIN - R         NaN          NaN
# 4  R/O VANCOMYCIN RESISTANT ENTEROCOCCUS         NaN          NaN
#
#    event_location
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
